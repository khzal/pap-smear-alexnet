# %% [markdown]
# # **Mengimport dataset**
#
# In this step, the dataset is being imported by stating where we put the source image, then divide those image into training and validation folder. Here is the guide about what the variable states (change it according to your directory):
#
# base_dir -> the main directory which consist of 3 folder (bahan, latih, and validasi)
#
# bahan_dir->states the directory of folder bahan
#
# train_dir->states the directory of folder latih
#
# validation->states the directory of folder validasi

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir= '/content/drive/MyDrive/alexresing/2_klasifikasiv.2'
# !ls "/content/drive/MyDrive/alexresing/2_klasifikasiv.2"
# Out:
# bahan  latih  validasi

# %%
bahan_dir =os.path.join(base_dir,'bahan')
train_dir =os.path.join(base_dir,'latih')
validation_dir =os.path.join(base_dir,'validasi')

# %% [markdown]
# to be changed according to your own directory
#
# normal_dir-> states the directory of images dataset of normal cell as the 1st class of classification
#
# dysplastic_dir->states the directory of images dataset of dysplastic cell as the 2nd class of classification
#
# train_normal->states the directory of train folder of the 1st class. leave it empty first because it will get filled in the next steps
#
# train_dysplastic->states the directory of train folder of the 2nd class. leave it empty first because it will get filled in the next steps
#
# validation_normal->states the directory of validation folder of the 1st class. leave it empty first because it will get filled in the next steps
#
# validation_normal->states the directory of validation folder of the 2nd class. leave it empty first because it will get filled in the next steps

# %%
#direktori bahan
normal_dir=os.path.join(bahan_dir, 'normal/')
dysplastic_dir=os.path.join(bahan_dir,'dysplastic/')

print('jumlah data train tiap kelas')
print('jumlah data 1:', len(os.listdir(normal_dir)))
print('jumlah data 2:', len(os.listdir(dysplastic_dir)))

#direktori train
train_normal= os.path.join(train_dir,'normal/')
train_dysplastic=os.path.join(train_dir,'dysplastic/')
#direktori validation
validation_normal= os.path.join(validation_dir,'normal/')
validation_dysplastic=os.path.join(validation_dir,'dysplastic/')
# Out:
# jumlah data train tiap kelas
# jumlah data 1: 157
# jumlah data 2: 198

# %% [markdown]
# # **Prepare the dataset**
#
# In this steps, the dataset is being prepared by going through several process such as randomize, generation of new data, etc
#
# .
#
# things to change:
#
# train_ratio: set the ratio of the train and validation data. example: if you have 100 images in dataset and you set the ratio to 0.8, there will be 80 images used for training and 20 images used for testing
#
# source_number(e.g 01,02,...)-> use the directory of one of the class in the dataset (bahan) folder
#
# train__number(e.g 01,02,...)-> use the directory of one of the class in training (latih) folder
#
# validation_number(e.g 01,02,...)-> use the directory of one of the class in the testing (validasi) folder

# %% [markdown]
# # *NOTE!!! ->don't run this section if you have divided the data into training and validation. Otherwise the file inside will get duplicate*

# %%
import random
from shutil import copyfile

def train_val_split(source,train,val,train_ratio):
  total_size=len(os.listdir(source))
  train_size=int(train_ratio * total_size)
  val_size=(total_size - train_size )

  randomized=random.sample(os.listdir(source),total_size)
  train_files=randomized[0:train_size]
  val_files=randomized[train_size:total_size]

  for i in train_files:
    i_file=source+i
    destination=train+i
    copyfile(i_file, destination)
  for i in val_files:
    i_file=source+i
    destination=val+i
    copyfile(i_file, destination)
  
#rasio data train dan test
train_ratio=0.9
  
#normal
source_00=normal_dir
train_00=train_normal
val_00=validation_normal
train_val_split(source_00,train_00,val_00,train_ratio)
#dysplastic
source_01=dysplastic_dir
train_01=train_dysplastic
val_01=validation_dysplastic
train_val_split(source_01,train_01,val_01,train_ratio)

# %% [markdown]
# # You can directly run this section if the data has already divided into training and testing

# %%
print('jumlah all normal: ',len(os.listdir(normal_dir)))
print('jumlah train normal: ',len(os.listdir(train_normal)))
print('jumlah validation normal: ',len(os.listdir(validation_normal)))

print('\njumlah all normal: ',len(os.listdir(dysplastic_dir)))
print('jumlah train normal: ',len(os.listdir(train_dysplastic)))
print('jumlah validation normal: ',len(os.listdir(validation_dysplastic)))
# Out:
# jumlah all normal:  157
# jumlah train normal:  141
# jumlah validation normal:  16
#
# jumlah all normal:  198
# jumlah train normal:  178
# jumlah validation normal:  20

# %% [markdown]
# **Preprocessing**
#
# In this section, new data is being generated in train_datagen and val_datagen using the criteria inside the ImageDataGenerator()

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    shear_range=0.1,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
    
)
val_datagen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    shear_range=0.1,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1

)

# %% [markdown]
# note: make sure that the target_size is equal as the input_size in the next section

# %%
train_generator=train_datagen.flow_from_directory(
    train_dir,
    target_size=(227,227),
    batch_size=256,
    class_mode='categorical'
)
val_generator=val_datagen.flow_from_directory(
    validation_dir,
    target_size=(227,227),
    batch_size=256,
    class_mode ='categorical'
)
# Out:
# Found 318 images belonging to 2 classes.
# Found 36 images belonging to 2 classes.

# %%
type(train_generator)
type(train_datagen)

print("Batch Size for Input Image : ",train_generator[0][0].shape)
print("Batch Size for Output Image : ",train_generator[0][1].shape)
print("Image Size of first image : ",train_generator[0][0][0].shape)
print("Output of first image : ",train_generator[0][1][0].shape)
# Out:
# Batch Size for Input Image :  (256, 227, 227, 3)
# Batch Size for Output Image :  (256, 2)
# Image Size of first image :  (227, 227, 3)
# Output of first image :  (2,)

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

fig , axs = plt.subplots(2,3 ,figsize = (10,10))
axs[0][0].imshow(train_generator[0][0][12])
axs[0][1].imshow(train_generator[0][0][10])
axs[0][2].imshow(train_generator[0][0][5])
axs[1][0].imshow(train_generator[0][0][20])
axs[1][1].imshow(train_generator[0][0][25])
axs[1][2].imshow(train_generator[0][0][3])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs={}):
    if(logs.get('accuracy')>0.91):
      print('\nAkurasi mencapai 91%')
      self.model.stop_training=True

callbacks = myCallback()

# %% [markdown]
# # **TRAINING**
#
# you can customize your own architecture by adding or removing layer, change the parameters such as the activation function, padding,etc. In this code, I use the alexnet architecture showed in this diagram
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Note: make sure that input_shape is equal as target_size in the previous value and the last layer_dense equal to number of class

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Dense, Activation,BatchNormalization, Flatten, Conv2D, MaxPooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
input_shape=(227,227,3)


def AlexNet(input_shape):
    
    X_input = Input(input_shape)
    
    X = Conv2D(96,(11,11),strides = 4,name="conv0")(X_input)
    X = BatchNormalization(axis = 3 , name = "bn0")(X)
    X = Activation('relu')(X)
    
    X = MaxPooling2D((3,3),strides = 2,name = 'max0')(X)
    
    X = Conv2D(256,(5,5),padding = 'same' , name = 'conv1')(X)
    X = BatchNormalization(axis = 3 ,name='bn1')(X)
    X = Activation('relu')(X)
    
    X = MaxPooling2D((3,3),strides = 2,name = 'max1')(X)
    
    X = Conv2D(384, (3,3) , padding = 'same' , name='conv2')(X)
    X = BatchNormalization(axis = 3, name = 'bn2')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(384, (3,3) , padding = 'same' , name='conv3')(X)
    X = BatchNormalization(axis = 3, name = 'bn3')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(256, (3,3) , padding = 'same' , name='conv4')(X)
    X = BatchNormalization(axis = 3, name = 'bn4')(X)
    X = Activation('relu')(X)
    
    X = MaxPooling2D((3,3),strides = 2,name = 'max2')(X)
    
    X = Flatten()(X)
    
    X = Dense(4096, activation = 'relu', name = "fc0")(X)
    
    X = Dense(4096, activation = 'relu', name = 'fc1')(X) 
    
    X = Dense(2,activation='softmax',name = 'fc2')(X)
    
    model = Model(inputs = X_input, outputs = X, name='AlexNet')
    return model

# %%
alex = AlexNet(train_generator[0][0].shape[1:])

# %%
alex.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv0 (Conv2D)              (None, 55, 55, 96)        34944
#
#  bn0 (BatchNormalization)    (None, 55, 55, 96)        384
#
#  activation_20 (Activation)  (None, 55, 55, 96)        0
#
#  max0 (MaxPooling2D)         (None, 27, 27, 96)        0
#
#  conv1 (Conv2D)              (None, 27, 27, 256)       614656
#
#  bn1 (BatchNormalization)    (None, 27, 27, 256)       1024
#
#  activation_21 (Activation)  (None, 27, 27, 256)       0
#
#  max1 (MaxPooling2D)         (None, 13, 13, 256)       0
#
#  conv2 (Conv2D)              (None, 13, 13, 384)       885120
#
#  bn2 (BatchNormalization)    (None, 13, 13, 384)       1536
#
#  activation_22 (Activation)  (None, 13, 13, 384)       0
#
#  conv3 (Conv2D)              (None, 13, 13, 384)       1327488
#
#  bn3 (BatchNormalization)    (None, 13, 13, 384)       1536
#
#  activation_23 (Activation)  (None, 13, 13, 384)       0
#
#  conv4 (Conv2D)              (None, 13, 13, 256)       884992
#
#  bn4 (BatchNormalization)    (None, 13, 13, 256)       1024
#
#  activation_24 (Activation)  (None, 13, 13, 256)       0
#
#  max2 (MaxPooling2D)         (None, 6, 6, 256)         0
#
#  flatten_4 (Flatten)         (None, 9216)              0
#
#  fc0 (Dense)                 (None, 4096)              37752832
#
#  fc1 (Dense)                 (None, 4096)              16781312
#
#  fc2 (Dense)                 (None, 2)                 8194
#
# =================================================================
# Total params: 58,295,042
# Trainable params: 58,292,290
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
alex.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics=['accuracy'])

# %%
history=alex.fit(train_generator,
         #steps_per_epoch=12, #-->dimatikan karena sistem tidak kuat jadi menyesuaikan
         epochs=100,
         validation_data=val_generator,
         #validation_steps= 1,
         verbose=1,
         callbacks= [callbacks])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 6s 2s/step - loss: 26.0271 - accuracy: 0.5189 - val_loss: 36.3534 - val_accuracy: 0.5556
# Epoch 2/100
# 2/2 [==============================] - 4s 1s/step - loss: 143.2271 - accuracy: 0.5566 - val_loss: 215.1584 - val_accuracy: 0.5556
# Epoch 3/100
# 2/2 [==============================] - 5s 4s/step - loss: 6.2752 - accuracy: 0.5566 - val_loss: 401.6884 - val_accuracy: 0.4444
# Epoch 4/100
# 2/2 [==============================] - 4s 1s/step - loss: 15.0866 - accuracy: 0.4434 - val_loss: 378.5946 - val_accuracy: 0.4444
# Epoch 5/100
# 2/2 [==============================] - 4s 1s/step - loss: 6.1778 - accuracy: 0.4843 - val_loss: 444.0811 - val_accuracy: 0.5556
# Epoch 6/100
# 2/2 [==============================] - 5s 4s/step - loss: 2.9542 - accuracy: 0.5566 - val_loss: 836.3793 - val_accuracy: 0.5556
# Epoch 7/100
# 2/2 [==============================] - 4s 1s/step - loss: 3.3526 - accuracy: 0.5566 - val_loss: 741.0931 - val_accuracy: 0.5556
# Epoch 8/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.9673 - accuracy: 0.5566 - val_loss: 415.1918 - val_accuracy: 0.5556
# Epoch 9/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3244 - accuracy: 0.5629 - val_loss: 88.3551 - val_accuracy: 0.5556
# Epoch 10/100
# 2/2 [==============================] - 5s 4s/step - loss: 1.2375 - accuracy: 0.5409 - val_loss: 79.2785 - val_accuracy: 0.4444
# Epoch 11/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2825 - accuracy: 0.4937 - val_loss: 14.7509 - val_accuracy: 0.5556
# Epoch 12/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.7329 - accuracy: 0.6132 - val_loss: 57.5686 - val_accuracy: 0.5556
# Epoch 13/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.7387 - accuracy: 0.5157 - val_loss: 44.3914 - val_accuracy: 0.5556
# Epoch 14/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.7228 - accuracy: 0.5566 - val_loss: 19.6579 - val_accuracy: 0.5556
# Epoch 15/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.6548 - accuracy: 0.5660 - val_loss: 4.2738 - val_accuracy: 0.5000
# Epoch 16/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.6633 - accuracy: 0.6069 - val_loss: 14.7983 - val_accuracy: 0.4444
# Epoch 17/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6841 - accuracy: 0.5692 - val_loss: 1.6170 - val_accuracy: 0.6944
# Epoch 18/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6213 - accuracy: 0.6321 - val_loss: 5.5525 - val_accuracy: 0.5556
# Epoch 19/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.6247 - accuracy: 0.6478 - val_loss: 6.8894 - val_accuracy: 0.5556
# Epoch 20/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6313 - accuracy: 0.6509 - val_loss: 4.8436 - val_accuracy: 0.5556
# Epoch 21/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.6163 - accuracy: 0.6635 - val_loss: 1.3246 - val_accuracy: 0.6667
# Epoch 22/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.6072 - accuracy: 0.6541 - val_loss: 0.6414 - val_accuracy: 0.7222
# Epoch 23/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.6034 - accuracy: 0.6509 - val_loss: 0.4579 - val_accuracy: 0.8333
# Epoch 24/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5922 - accuracy: 0.6604 - val_loss: 0.6463 - val_accuracy: 0.7222
# Epoch 25/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5950 - accuracy: 0.6635 - val_loss: 1.0180 - val_accuracy: 0.6389
# Epoch 26/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.6051 - accuracy: 0.6635 - val_loss: 0.5535 - val_accuracy: 0.7500
# Epoch 27/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6008 - accuracy: 0.6604 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 28/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5976 - accuracy: 0.5660 - val_loss: 0.5365 - val_accuracy: 0.7500
# Epoch 29/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.6028 - accuracy: 0.5723 - val_loss: 0.5950 - val_accuracy: 0.7222
# Epoch 30/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.5869 - accuracy: 0.6918 - val_loss: 0.4461 - val_accuracy: 0.8056
# Epoch 31/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5924 - accuracy: 0.6572 - val_loss: 0.6704 - val_accuracy: 0.6667
# Epoch 32/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5943 - accuracy: 0.6572 - val_loss: 0.5238 - val_accuracy: 0.7222
# Epoch 33/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.5912 - accuracy: 0.6667 - val_loss: 0.5250 - val_accuracy: 0.7222
# Epoch 34/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5830 - accuracy: 0.6730 - val_loss: 0.5052 - val_accuracy: 0.7500
# Epoch 35/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5809 - accuracy: 0.6792 - val_loss: 0.4519 - val_accuracy: 0.7500
# Epoch 36/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.5759 - accuracy: 0.6761 - val_loss: 0.5019 - val_accuracy: 0.7500
# Epoch 37/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.5704 - accuracy: 0.6824 - val_loss: 0.5806 - val_accuracy: 0.7500
# Epoch 38/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.5674 - accuracy: 0.6761 - val_loss: 0.5366 - val_accuracy: 0.7222
# Epoch 39/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.5725 - accuracy: 0.6730 - val_loss: 0.5440 - val_accuracy: 0.7222
# Epoch 40/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5636 - accuracy: 0.6792 - val_loss: 0.5977 - val_accuracy: 0.7500
# Epoch 41/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5689 - accuracy: 0.6792 - val_loss: 0.5618 - val_accuracy: 0.7222
# Epoch 42/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5601 - accuracy: 0.6698 - val_loss: 0.5383 - val_accuracy: 0.7222
# Epoch 43/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5714 - accuracy: 0.6572 - val_loss: 0.6904 - val_accuracy: 0.6389
# Epoch 44/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5797 - accuracy: 0.6667 - val_loss: 0.9082 - val_accuracy: 0.6389
# Epoch 45/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5780 - accuracy: 0.6824 - val_loss: 0.5820 - val_accuracy: 0.6667
# Epoch 46/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5683 - accuracy: 0.7421 - val_loss: 0.7295 - val_accuracy: 0.6667
# Epoch 47/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5804 - accuracy: 0.8050 - val_loss: 0.5936 - val_accuracy: 0.6944
# Epoch 48/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5664 - accuracy: 0.6918 - val_loss: 0.6291 - val_accuracy: 0.6944
# Epoch 49/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5632 - accuracy: 0.6855 - val_loss: 0.6382 - val_accuracy: 0.6111
# Epoch 50/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.5507 - accuracy: 0.6887 - val_loss: 0.5913 - val_accuracy: 0.5833
# Epoch 51/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5553 - accuracy: 0.6887 - val_loss: 0.6277 - val_accuracy: 0.5833
# Epoch 52/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5420 - accuracy: 0.6918 - val_loss: 0.5715 - val_accuracy: 0.6111
# Epoch 53/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5422 - accuracy: 0.6981 - val_loss: 0.6360 - val_accuracy: 0.6389
# Epoch 54/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5327 - accuracy: 0.6918 - val_loss: 0.6095 - val_accuracy: 0.5833
# Epoch 55/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5310 - accuracy: 0.6918 - val_loss: 0.6543 - val_accuracy: 0.5833
# Epoch 56/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5345 - accuracy: 0.7075 - val_loss: 0.5898 - val_accuracy: 0.5556
# Epoch 57/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5397 - accuracy: 0.6918 - val_loss: 0.6617 - val_accuracy: 0.5278
# Epoch 58/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5278 - accuracy: 0.6981 - val_loss: 0.5882 - val_accuracy: 0.5833
# Epoch 59/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.5093 - accuracy: 0.7170 - val_loss: 0.5829 - val_accuracy: 0.5278
# Epoch 60/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5107 - accuracy: 0.7264 - val_loss: 0.5817 - val_accuracy: 0.6111
# Epoch 61/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5107 - accuracy: 0.7233 - val_loss: 0.5529 - val_accuracy: 0.6111
# Epoch 62/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.5130 - accuracy: 0.7610 - val_loss: 0.5427 - val_accuracy: 0.7500
# Epoch 63/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.4889 - accuracy: 0.7987 - val_loss: 0.5365 - val_accuracy: 0.7222
# Epoch 64/100
# 2/2 [==============================] - 6s 1s/step - loss: 0.4608 - accuracy: 0.8019 - val_loss: 0.4984 - val_accuracy: 0.6944
# Epoch 65/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.4793 - accuracy: 0.7296 - val_loss: 0.5013 - val_accuracy: 0.7500
# Epoch 66/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.4434 - accuracy: 0.7893 - val_loss: 0.4525 - val_accuracy: 0.8611
# Epoch 67/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.4302 - accuracy: 0.8333 - val_loss: 0.4447 - val_accuracy: 0.8333
# Epoch 68/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.3995 - accuracy: 0.8302 - val_loss: 0.4380 - val_accuracy: 0.7778
# Epoch 69/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3869 - accuracy: 0.8365 - val_loss: 0.4594 - val_accuracy: 0.7500
# Epoch 70/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3735 - accuracy: 0.8145 - val_loss: 0.4548 - val_accuracy: 0.7778
# Epoch 71/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.3583 - accuracy: 0.8491 - val_loss: 0.4246 - val_accuracy: 0.8611
# Epoch 72/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3519 - accuracy: 0.8491 - val_loss: 0.5241 - val_accuracy: 0.7500
# Epoch 73/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.3322 - accuracy: 0.8491 - val_loss: 0.5255 - val_accuracy: 0.7222
# Epoch 74/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.3508 - accuracy: 0.8428 - val_loss: 0.4871 - val_accuracy: 0.7778
# Epoch 75/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3458 - accuracy: 0.8742 - val_loss: 0.5498 - val_accuracy: 0.6944
# Epoch 76/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3218 - accuracy: 0.8428 - val_loss: 0.6664 - val_accuracy: 0.6944
# Epoch 77/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.3237 - accuracy: 0.8553 - val_loss: 0.6073 - val_accuracy: 0.6944
# Epoch 78/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3267 - accuracy: 0.8553 - val_loss: 0.5792 - val_accuracy: 0.7222
# Epoch 79/100
# 2/2 [==============================] - 6s 4s/step - loss: 0.3005 - accuracy: 0.8616 - val_loss: 0.5989 - val_accuracy: 0.6667
# Epoch 80/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.3372 - accuracy: 0.8585 - val_loss: 0.6210 - val_accuracy: 0.7222
# Epoch 81/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.2972 - accuracy: 0.8836 - val_loss: 0.4674 - val_accuracy: 0.8056
# Epoch 82/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3051 - accuracy: 0.8868 - val_loss: 0.4765 - val_accuracy: 0.7500
# Epoch 83/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3309 - accuracy: 0.8648 - val_loss: 0.5955 - val_accuracy: 0.7222
# Epoch 84/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.2942 - accuracy: 0.8836 - val_loss: 0.5551 - val_accuracy: 0.6667
# Epoch 85/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.2773 - accuracy: 0.8805 - val_loss: 0.4996 - val_accuracy: 0.7778
# Epoch 86/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.2688 - accuracy: 0.8994 - val_loss: 0.5520 - val_accuracy: 0.6944
# Epoch 87/100
# 2/2 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9151
# Akurasi mencapai 91%
# 2/2 [==============================] - 4s 1s/step - loss: 0.2384 - accuracy: 0.9151 - val_loss: 0.5687 - val_accuracy: 0.6944

# %%
val_generator=val_datagen.flow_from_directory(
    validation_dir,
    target_size=(227,227),
    batch_size=256,
    class_mode ='categorical'
)
# Out:
# Found 36 images belonging to 2 classes.

# %%
preds = alex.evaluate(val_generator)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 1/1 [==============================] - 0s 477ms/step - loss: 0.5572 - accuracy: 0.7222
# Loss = 0.5571949481964111
# Test Accuracy = 0.7222222089767456

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

plt.plot(epochs,acc,'r',label='training accuracy')
plt.plot(epochs,val_acc,'g',label='validation accuracy')
plt.title('akurasi validasi dan training')
plt.legend(loc='best')
plt.show()

plt.plot(epochs,loss,'r',label='training loss')
plt.plot(epochs,val_loss,'g',label='validation loss')
plt.title('loss validasi dan training')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # **Lets Classify!!**

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files
class_list=os.listdir(train_dir)
print('Data dapat dikelompokan menjadi: ', class_list)
uploaded=files.upload()
# Out:
# Data dapat dikelompokan menjadi:  ['dysplastic', 'normal']
#      <input type="file" id="files-0e3e81b6-28ab-4cf1-b62a-e4ab687f3158" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e3e81b6-28ab-4cf1-b62a-e4ab687f3158">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#untuk gambar upload
prediksi='/content/classify/'
predict_datagen=ImageDataGenerator(rescale=1./255)
predict=predict_datagen.flow_from_directory(
    prediksi,
    target_size=(227,227),
    batch_size=1,
    class_mode='categorical'
)

image_num=0
predictions = alex.predict(predict)
imshow(predict[image_num][0][0])
print(predictions[image_num])

nilai = tf.nn.softmax(predictions[image_num])

print(
      "Ini adalah gambar {} dengan persentase keyakinan {:.2f}"
      .format(class_list[np.argmax(nilai)], 100 * np.max(nilai))
      )
print(class_list[np.argmax(nilai)])
# Out:
# Found 1 images belonging to 2 classes.
# [0.95652306 0.04347691]
# Ini adalah gambar dysplastic dengan persentase keyakinan 71.36
# dysplastic

# %% [markdown]
# note: for 'prediksi' folder make sure that we place the image inside 1 folder first, so the system will read there is some images in 1 classes

# %%
#untuk gambar lain
prediksi='/content/drive/MyDrive/alexresing/ujian/'
predict_datagen=ImageDataGenerator(rescale=1./255)
predict=predict_datagen.flow_from_directory(
    prediksi,
    target_size=(227,227),
    batch_size=1,
    class_mode='categorical'
)


image_num=8
predictions = alex.predict(predict)
imshow(predict[image_num][0][0])
print(predictions[image_num])

nilai = tf.nn.softmax(predictions[image_num])

print(
      "Ini adalah gambar {} dengan persentase keyakinan {:.2f}"
      .format(class_list[np.argmax(nilai)], 100 * np.max(nilai))
      )
# Out:
# Found 29 images belonging to 1 classes.
# [0.2554011 0.7445989]
# Ini adalah gambar normal dengan persentase keyakinan 61.99

# %%
# gambar1
nilai_pred1=tf.nn.softmax(predictions[13])
pred1=class_list[np.argmax(nilai_pred1)]
perstage1=100 * np.max(nilai_pred1)
judul1="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred1)], 100 * np.max(nilai_pred1))
#gambar2
nilai_pred2=tf.nn.softmax(predictions[10])
pred2=class_list[np.argmax(nilai_pred2)]
perstage2=100 * np.max(nilai_pred2)
judul2="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred2)], 100 * np.max(nilai_pred2))
#gambar3
nilai_pred3=tf.nn.softmax(predictions[5])
pred3=class_list[np.argmax(nilai_pred3)]
perstage3=100 * np.max(nilai_pred3)
judul3="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred3)], 100 * np.max(nilai_pred3))
#gambar4
nilai_pred4=tf.nn.softmax(predictions[18])
pred4=class_list[np.argmax(nilai_pred4)]
perstage4=100 * np.max(nilai_pred4)
judul4="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred4)], 100 * np.max(nilai_pred4))
#gambar5
nilai_pred5=tf.nn.softmax(predictions[7])
pred5=class_list[np.argmax(nilai_pred5)]
perstage5=100 * np.max(nilai_pred5)
judul5="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred5)], 100 * np.max(nilai_pred5))
#gambar6
nilai_pred6=tf.nn.softmax(predictions[6])
pred6=class_list[np.argmax(nilai_pred6)]
perstage6=100 * np.max(nilai_pred6)
judul6="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred6)], 100 * np.max(nilai_pred6))

#def get_category(predicted_output):
#  class_list
#  return os.listdir(train_dir)[np.argmax(abc)]
#-somehow fuction above can be used to shortening this part

# %%
fig , axs = plt.subplots(2,3 ,figsize = (10,10))

axs[0][0].imshow(predict[13][0][0])
axs[0][0].set_title(judul1)

axs[0][1].imshow(predict[10][0][0])
axs[0][1].set_title(judul2)

axs[0][2].imshow(predict[5][0][0])
axs[0][2].set_title(judul3)

axs[1][0].imshow(predict[18][0][0])
axs[1][0].set_title(judul4)

axs[1][1].imshow(predict[7][0][0])
axs[1][1].set_title(judul5)

axs[1][2].imshow(predict[6][0][0])
axs[1][2].set_title(judul6)
# Out:
# Text(0.5, 1.0, 'dysplastic  55.81%')
