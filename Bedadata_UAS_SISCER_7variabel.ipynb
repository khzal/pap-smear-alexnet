# %% [markdown]
# # **Mengimport dataset**
#
# In this step, the dataset is being imported by stating where we put the source image, then divide those image into training and validation folder. Here is the guide about what the variable states (change it according to your directory):
#
# base_dir -> the main directory which consist of 3 folder (bahan, latih, and validasi)
#
# bahan_dir->states the directory of folder bahan
#
# train_dir->states the directory of folder latih
#
# validation->states the directory of folder validasi

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir= '/content/drive/MyDrive/folderr/7_klasifikasi'
# !ls "/content/drive/MyDrive/folderr/7_klasifikasi"
# Out:
# bahan  latih  validasi

# %%
bahan_dir =os.path.join(base_dir,'bahan')
train_dir =os.path.join(base_dir,'latih')
validation_dir =os.path.join(base_dir,'validasi')

# %% [markdown]
# to be changed according to your own directory
#
# normal_dir-> states the directory of images dataset of normal cell as the 1st class of classification
#
# dysplastic_dir->states the directory of images dataset of dysplastic cell as the 2nd class of classification
#
# train_normal->states the directory of train folder of the 1st class. leave it empty first because it will get filled in the next steps
#
# train_dysplastic->states the directory of train folder of the 2nd class. leave it empty first because it will get filled in the next steps
#
# validation_normal->states the directory of validation folder of the 1st class. leave it empty first because it will get filled in the next steps
#
# validation_normal->states the directory of validation folder of the 2nd class. leave it empty first because it will get filled in the next steps

# %%
#direktori bahan
carcinoma_in_situ_dir=os.path.join(bahan_dir, 'carcinoma_in_situ/')
light_dysplastic_dir=os.path.join(bahan_dir,'light_dysplastic/')
moderate_dysplastic_dir=os.path.join(bahan_dir,'moderate_dysplastic/')
normal_columnar_dir=os.path.join(bahan_dir,'normal_columnar/')
normal_intermediate_dir=os.path.join(bahan_dir,'normal_intermediate/')
normal_superficiel_dir=os.path.join(bahan_dir,'normal_superficiel/')
severe_dysplastic_dir=os.path.join(bahan_dir,'severe_dysplastic/')


print('jumlah data train tiap kelas')
print('jumlah data 1:', len(os.listdir(carcinoma_in_situ_dir)))
print('jumlah data 2:', len(os.listdir(light_dysplastic_dir)))
print('jumlah data 3:', len(os.listdir(moderate_dysplastic_dir)))
print('jumlah data 4:', len(os.listdir(normal_columnar_dir)))
print('jumlah data 5:', len(os.listdir(normal_intermediate_dir)))
print('jumlah data 6:', len(os.listdir(normal_superficiel_dir)))
print('jumlah data 7:', len(os.listdir(severe_dysplastic_dir)))


#direktori train
train_carcinoma_in_situ= os.path.join(train_dir,'carcinoma_in_situ/')
train_light_dysplastic=os.path.join(train_dir,'light_dysplastic/')
train_moderate_dysplastic=os.path.join(train_dir,'moderate_dysplastic/')
train_normal_columnar=os.path.join(train_dir,'normal_columnar/')
train_normal_intermediate=os.path.join(train_dir,'normal_intermediate/')
train_normal_superficiel=os.path.join(train_dir,'normal_superficiel/')
train_severe_dysplastic=os.path.join(train_dir,'severe_dysplastic/')


#direktori validation
validation_carcinoma_in_situ= os.path.join(validation_dir,'carcinoma_in_situ/')
validation_light_dysplastic=os.path.join(validation_dir,'light_dysplastic/')
validation_moderate_dysplastic=os.path.join(validation_dir,'moderate_dysplastic/')
validation_normal_columnar=os.path.join(validation_dir,'normal_columnar/')
validation_normal_intermediate=os.path.join(validation_dir,'normal_intermediate/')
validation_normal_superficiel=os.path.join(validation_dir,'normal_superficiel/')
validation_severe_dysplastic=os.path.join(validation_dir,'severe_dysplastic/')
# Out:
# jumlah data train tiap kelas
# jumlah data 1: 151
# jumlah data 2: 183
# jumlah data 3: 147
# jumlah data 4: 99
# jumlah data 5: 71
# jumlah data 6: 75
# jumlah data 7: 198

# %% [markdown]
# # **Prepare the dataset**
#
# In this steps, the dataset is being prepared by going through several process such as randomize, generation of new data, etc
#
# .
#
# things to change:
#
# train_ratio: set the ratio of the train and validation data. example: if you have 100 images in dataset and you set the ratio to 0.8, there will be 80 images used for training and 20 images used for testing
#
# source_number(e.g 01,02,...)-> use the directory of one of the class in the dataset (bahan) folder
#
# train__number(e.g 01,02,...)-> use the directory of one of the class in training (latih) folder
#
# validation_number(e.g 01,02,...)-> use the directory of one of the class in the testing (validasi) folder

# %% [markdown]
# # *NOTE!!! ->don't run this section if you have divided the data into training and validation. Otherwise the file inside will get duplicate*

# %%
import random
from shutil import copyfile

def train_val_split(source,train,val,train_ratio):
  total_size=len(os.listdir(source))
  train_size=int(train_ratio * total_size)
  val_size=(total_size - train_size )

  randomized=random.sample(os.listdir(source),total_size)
  train_files=randomized[0:train_size]
  val_files=randomized[train_size:total_size]

  for i in train_files:
    i_file=source+i
    destination=train+i
    copyfile(i_file, destination)
  for i in val_files:
    i_file=source+i
    destination=val+i
    copyfile(i_file, destination)
  
#rasio data train dan test
train_ratio=0.9
  
#carcinoma_in_situ
source_00=carcinoma_in_situ_dir
train_00=train_carcinoma_in_situ
val_00=validation_carcinoma_in_situ
train_val_split(source_00,train_00,val_00,train_ratio)

#light_dysplastic
source_01=light_dysplastic_dir
train_01=train_light_dysplastic
val_01=validation_light_dysplastic
train_val_split(source_01,train_01,val_01,train_ratio)

#moderate_dysplastic
source_02=moderate_dysplastic_dir
train_02=train_moderate_dysplastic
val_02=validation_moderate_dysplastic
train_val_split(source_02,train_02,val_02,train_ratio)

#normal_columnar
source_03=normal_columnar_dir
train_03=train_normal_columnar
val_03=validation_normal_columnar
train_val_split(source_03,train_03,val_03,train_ratio)

#normal_intermediate
source_04=normal_intermediate_dir
train_04=train_normal_intermediate
val_04=validation_normal_intermediate
train_val_split(source_04,train_04,val_04,train_ratio)

#normal_superficiel
source_05=normal_superficiel_dir
train_05=train_normal_superficiel
val_05=validation_normal_superficiel
train_val_split(source_05,train_05,val_05,train_ratio)

#severe_dysplastic
source_06=severe_dysplastic_dir
train_06=train_severe_dysplastic
val_06=validation_severe_dysplastic
train_val_split(source_06,train_06,val_06,train_ratio)

# %% [markdown]
# # You can directly run this section if the data has already divided into training and testing

# %%
print('jumlah all carcinoma_in_situ: ',len(os.listdir(carcinoma_in_situ_dir)))
print('jumlah train carcinoma_in_situ: ',len(os.listdir(train_carcinoma_in_situ)))
print('jumlah validation carcinoma_in_situ: ',len(os.listdir(validation_carcinoma_in_situ)))

print('\njumlah all light_dysplastic: ',len(os.listdir(light_dysplastic_dir)))
print('jumlah train light_dysplastic: ',len(os.listdir(train_light_dysplastic)))
print('jumlah validation light_dysplastic: ',len(os.listdir(validation_light_dysplastic)))

print('\njumlah all moderate_dysplastic: ',len(os.listdir(moderate_dysplastic_dir)))
print('jumlah train moderate_dysplastic: ',len(os.listdir(train_moderate_dysplastic)))
print('jumlah validation moderate_dysplastic: ',len(os.listdir(validation_moderate_dysplastic)))

print('\njumlah all normal_columnar: ',len(os.listdir(normal_columnar_dir)))
print('jumlah train normal_columnar: ',len(os.listdir(train_normal_columnar)))
print('jumlah validation normal_columnar: ',len(os.listdir(validation_normal_columnar)))

print('\njumlah all normal_intermediate: ',len(os.listdir(normal_intermediate_dir)))
print('jumlah train normal_intermediate: ',len(os.listdir(train_normal_intermediate)))
print('jumlah validation normal_intermediate: ',len(os.listdir(validation_normal_intermediate)))

print('\njumlah all normal_superficiel: ',len(os.listdir(normal_superficiel_dir)))
print('jumlah train normal_superficiel: ',len(os.listdir(train_normal_superficiel)))
print('jumlah validation normal_superficiel: ',len(os.listdir(validation_normal_superficiel)))

print('\njumlah all severe_dysplastic: ',len(os.listdir(severe_dysplastic_dir)))
print('jumlah train severe_dysplastic: ',len(os.listdir(train_severe_dysplastic)))
print('jumlah validation severe_dysplastic: ',len(os.listdir(validation_severe_dysplastic)))
# Out:
# jumlah all carcinoma_in_situ:  151
# jumlah train carcinoma_in_situ:  135
# jumlah validation carcinoma_in_situ:  16
#
# jumlah all light_dysplastic:  183
# jumlah train light_dysplastic:  164
# jumlah validation light_dysplastic:  19
#
# jumlah all moderate_dysplastic:  147
# jumlah train moderate_dysplastic:  132
# jumlah validation moderate_dysplastic:  15
#
# jumlah all normal_columnar:  99
# jumlah train normal_columnar:  89
# jumlah validation normal_columnar:  10
#
# jumlah all normal_intermediate:  71
# jumlah train normal_intermediate:  63
# jumlah validation normal_intermediate:  8
#
# jumlah all normal_superficiel:  75
# jumlah train normal_superficiel:  67
# jumlah validation normal_superficiel:  8
#
# jumlah all severe_dysplastic:  198
# jumlah train severe_dysplastic:  178
# jumlah validation severe_dysplastic:  20

# %% [markdown]
# **Preprocessing**
#
# In this section, new data is being generated in train_datagen and val_datagen using the criteria inside the ImageDataGenerator()

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    shear_range=0.1,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)
val_datagen=ImageDataGenerator(
     rescale=1./255,
    rotation_range=5,
    shear_range=0.1,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)

# %% [markdown]
# note: make sure that the target_size is equal as the input_size in the next section

# %%
train_generator=train_datagen.flow_from_directory(
    train_dir,
    target_size=(227,227),
    batch_size=128,
    class_mode='categorical'
)
val_generator=val_datagen.flow_from_directory(
    validation_dir,
    target_size=(227,227),
    batch_size=32,
    class_mode ='categorical'
)
# Out:
# Found 824 images belonging to 7 classes.
# Found 93 images belonging to 7 classes.

# %%
type(train_generator)
type(train_datagen)

print("Batch Size for Input Image : ",train_generator[0][0].shape)
print("Batch Size for Output Image : ",train_generator[0][1].shape)
print("Image Size of first image : ",train_generator[0][0][0].shape)
print("Output of first image : ",train_generator[0][1][0].shape)
# Out:
# Batch Size for Input Image :  (128, 227, 227, 3)
# Batch Size for Output Image :  (128, 7)
# Image Size of first image :  (227, 227, 3)
# Output of first image :  (7,)

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

fig , axs = plt.subplots(2,3 ,figsize = (10,10))
axs[0][0].imshow(train_generator[0][0][12])
axs[0][1].imshow(train_generator[0][0][10])
axs[0][2].imshow(train_generator[0][0][5])
axs[1][0].imshow(train_generator[0][0][20])
axs[1][1].imshow(train_generator[0][0][25])
axs[1][2].imshow(train_generator[0][0][3])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs={}):
    if(logs.get('accuracy')>0.95):
      print('\nAkurasi mencapai 95%')
      self.model.stop_training=True

callbacks = myCallback()

# %% [markdown]
# # **TRAINING**
#
# you can customize your own architecture by adding or removing layer, change the parameters such as the activation function, padding,etc. In this code, I use the alexnet architecture showed in this diagram
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Note: make sure that input_shape is equal as target_size in the previous value and the last layer_dense equal to number of class

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Dense, Activation,BatchNormalization, Flatten, Conv2D, MaxPooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
input_shape=(227,227,3)


def AlexNet(input_shape):
    
    X_input = Input(input_shape)
    
    X = Conv2D(96,(11,11),strides = 4,name="conv0")(X_input)
    X = BatchNormalization(axis = 3 , name = "bn0")(X)
    X = Activation('relu')(X)
    
    X = MaxPooling2D((3,3),strides = 2,name = 'max0')(X)
    
    X = Conv2D(256,(5,5),padding = 'same' , name = 'conv1')(X)
    X = BatchNormalization(axis = 3 ,name='bn1')(X)
    X = Activation('relu')(X)
    
    X = MaxPooling2D((3,3),strides = 2,name = 'max1')(X)
    
    X = Conv2D(384, (3,3) , padding = 'same' , name='conv2')(X)
    X = BatchNormalization(axis = 3, name = 'bn2')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(384, (3,3) , padding = 'same' , name='conv3')(X)
    X = BatchNormalization(axis = 3, name = 'bn3')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(256, (3,3) , padding = 'same' , name='conv4')(X)
    X = BatchNormalization(axis = 3, name = 'bn4')(X)
    X = Activation('relu')(X)
    
    X = MaxPooling2D((3,3),strides = 2,name = 'max2')(X)
    
    X = Flatten()(X)
    
    X = Dense(4096, activation = 'relu', name = "fc0")(X)
    
    X = Dense(4096, activation = 'relu', name = 'fc1')(X) 
    
    X = Dense(7,activation='softmax',name = 'fc2')(X)
    
    model = Model(inputs = X_input, outputs = X, name='AlexNet')
    return model

# %%
alex = AlexNet(train_generator[0][0].shape[1:])

# %%
alex.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv0 (Conv2D)              (None, 55, 55, 96)        34944
#
#  bn0 (BatchNormalization)    (None, 55, 55, 96)        384
#
#  activation_5 (Activation)   (None, 55, 55, 96)        0
#
#  max0 (MaxPooling2D)         (None, 27, 27, 96)        0
#
#  conv1 (Conv2D)              (None, 27, 27, 256)       614656
#
#  bn1 (BatchNormalization)    (None, 27, 27, 256)       1024
#
#  activation_6 (Activation)   (None, 27, 27, 256)       0
#
#  max1 (MaxPooling2D)         (None, 13, 13, 256)       0
#
#  conv2 (Conv2D)              (None, 13, 13, 384)       885120
#
#  bn2 (BatchNormalization)    (None, 13, 13, 384)       1536
#
#  activation_7 (Activation)   (None, 13, 13, 384)       0
#
#  conv3 (Conv2D)              (None, 13, 13, 384)       1327488
#
#  bn3 (BatchNormalization)    (None, 13, 13, 384)       1536
#
#  activation_8 (Activation)   (None, 13, 13, 384)       0
#
#  conv4 (Conv2D)              (None, 13, 13, 256)       884992
#
#  bn4 (BatchNormalization)    (None, 13, 13, 256)       1024
#
#  activation_9 (Activation)   (None, 13, 13, 256)       0
#
#  max2 (MaxPooling2D)         (None, 6, 6, 256)         0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  fc0 (Dense)                 (None, 4096)              37752832
#
#  fc1 (Dense)                 (None, 4096)              16781312
#
#  fc2 (Dense)                 (None, 7)                 28679
#
# =================================================================
# Total params: 58,315,527
# Trainable params: 58,312,775
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
alex.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics=['accuracy'])

# %%
history=alex.fit(train_generator,
         #steps_per_epoch=50, #-->dimatikan karena sistem tidak kuat jadi menyesuaikan
         epochs=200,
         validation_data=val_generator,
         #validation_steps= 1,
         verbose=1,
         callbacks= [callbacks])
# Out:
# Epoch 1/200
# 7/7 [==============================] - 164s 21s/step - loss: 44.1597 - accuracy: 0.1566 - val_loss: 921.6641 - val_accuracy: 0.2151
# Epoch 2/200
# 7/7 [==============================] - 11s 2s/step - loss: 3.2491 - accuracy: 0.2367 - val_loss: 295.3729 - val_accuracy: 0.2258
# Epoch 3/200
# 7/7 [==============================] - 11s 2s/step - loss: 2.0133 - accuracy: 0.2585 - val_loss: 149.5931 - val_accuracy: 0.2258
# Epoch 4/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.8059 - accuracy: 0.2706 - val_loss: 79.8345 - val_accuracy: 0.1075
# Epoch 5/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.6848 - accuracy: 0.3265 - val_loss: 18.2968 - val_accuracy: 0.1183
# Epoch 6/200
# 7/7 [==============================] - 12s 2s/step - loss: 1.6337 - accuracy: 0.3216 - val_loss: 13.6729 - val_accuracy: 0.1290
# Epoch 7/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.6253 - accuracy: 0.3629 - val_loss: 8.7564 - val_accuracy: 0.1075
# Epoch 8/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5894 - accuracy: 0.3507 - val_loss: 3.0664 - val_accuracy: 0.2473
# Epoch 9/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5718 - accuracy: 0.3471 - val_loss: 4.0717 - val_accuracy: 0.1935
# Epoch 10/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5525 - accuracy: 0.3689 - val_loss: 2.8559 - val_accuracy: 0.2366
# Epoch 11/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5446 - accuracy: 0.3750 - val_loss: 2.6581 - val_accuracy: 0.2258
# Epoch 12/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5332 - accuracy: 0.3968 - val_loss: 2.6007 - val_accuracy: 0.1935
# Epoch 13/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5181 - accuracy: 0.3908 - val_loss: 2.1024 - val_accuracy: 0.2151
# Epoch 14/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5549 - accuracy: 0.3823 - val_loss: 2.1168 - val_accuracy: 0.1828
# Epoch 15/200
# 7/7 [==============================] - 12s 2s/step - loss: 1.5070 - accuracy: 0.3981 - val_loss: 2.0032 - val_accuracy: 0.1935
# Epoch 16/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4791 - accuracy: 0.4041 - val_loss: 1.8644 - val_accuracy: 0.1935
# Epoch 17/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4641 - accuracy: 0.4053 - val_loss: 1.8506 - val_accuracy: 0.2688
# Epoch 18/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4514 - accuracy: 0.4090 - val_loss: 1.8067 - val_accuracy: 0.2796
# Epoch 19/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4633 - accuracy: 0.4005 - val_loss: 1.9296 - val_accuracy: 0.2688
# Epoch 20/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4519 - accuracy: 0.4211 - val_loss: 1.8102 - val_accuracy: 0.3333
# Epoch 21/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4395 - accuracy: 0.4090 - val_loss: 1.8872 - val_accuracy: 0.2258
# Epoch 22/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4098 - accuracy: 0.4381 - val_loss: 1.9040 - val_accuracy: 0.2151
# Epoch 23/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4153 - accuracy: 0.4272 - val_loss: 1.8747 - val_accuracy: 0.2473
# Epoch 24/200
# 7/7 [==============================] - 13s 2s/step - loss: 1.4340 - accuracy: 0.4223 - val_loss: 1.9018 - val_accuracy: 0.2043
# Epoch 25/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3951 - accuracy: 0.4175 - val_loss: 1.9168 - val_accuracy: 0.2473
# Epoch 26/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3854 - accuracy: 0.4381 - val_loss: 1.9625 - val_accuracy: 0.2043
# Epoch 27/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3994 - accuracy: 0.4284 - val_loss: 1.9266 - val_accuracy: 0.2258
# Epoch 28/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3569 - accuracy: 0.4199 - val_loss: 1.9847 - val_accuracy: 0.2366
# Epoch 29/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3649 - accuracy: 0.4527 - val_loss: 2.0303 - val_accuracy: 0.1828
# Epoch 30/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.2926 - accuracy: 0.4648 - val_loss: 2.1109 - val_accuracy: 0.2366
# Epoch 31/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.2793 - accuracy: 0.4624 - val_loss: 2.0775 - val_accuracy: 0.2043
# Epoch 32/200
# 7/7 [==============================] - 12s 2s/step - loss: 1.2753 - accuracy: 0.4660 - val_loss: 1.9773 - val_accuracy: 0.2581
# Epoch 33/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.2065 - accuracy: 0.4939 - val_loss: 2.0396 - val_accuracy: 0.2796
# Epoch 34/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.2295 - accuracy: 0.4964 - val_loss: 1.8032 - val_accuracy: 0.2473
# Epoch 35/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.1989 - accuracy: 0.5267 - val_loss: 2.0125 - val_accuracy: 0.3441
# Epoch 36/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.1435 - accuracy: 0.5498 - val_loss: 1.9978 - val_accuracy: 0.2473
# Epoch 37/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.1518 - accuracy: 0.5279 - val_loss: 2.2688 - val_accuracy: 0.2581
# Epoch 38/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0977 - accuracy: 0.5655 - val_loss: 1.8929 - val_accuracy: 0.3441
# Epoch 39/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.1011 - accuracy: 0.5534 - val_loss: 1.8498 - val_accuracy: 0.3441
# Epoch 40/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0885 - accuracy: 0.5437 - val_loss: 1.9193 - val_accuracy: 0.3441
# Epoch 41/200
# 7/7 [==============================] - 12s 2s/step - loss: 1.0787 - accuracy: 0.5546 - val_loss: 2.0472 - val_accuracy: 0.3118
# Epoch 42/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0389 - accuracy: 0.5716 - val_loss: 1.9778 - val_accuracy: 0.3978
# Epoch 43/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0519 - accuracy: 0.5777 - val_loss: 1.9948 - val_accuracy: 0.3226
# Epoch 44/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0173 - accuracy: 0.5813 - val_loss: 2.5422 - val_accuracy: 0.3226
# Epoch 45/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0378 - accuracy: 0.5874 - val_loss: 1.8327 - val_accuracy: 0.4946
# Epoch 46/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0315 - accuracy: 0.5910 - val_loss: 2.4424 - val_accuracy: 0.3548
# Epoch 47/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9706 - accuracy: 0.5959 - val_loss: 3.6746 - val_accuracy: 0.1828
# Epoch 48/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9674 - accuracy: 0.6335 - val_loss: 3.6552 - val_accuracy: 0.2043
# Epoch 49/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0346 - accuracy: 0.6032 - val_loss: 4.7566 - val_accuracy: 0.1720
# Epoch 50/200
# 7/7 [==============================] - 12s 2s/step - loss: 1.0275 - accuracy: 0.5801 - val_loss: 3.9939 - val_accuracy: 0.2043
# Epoch 51/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9844 - accuracy: 0.5934 - val_loss: 4.5511 - val_accuracy: 0.1720
# Epoch 52/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.9476 - accuracy: 0.6274 - val_loss: 4.1216 - val_accuracy: 0.1935
# Epoch 53/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9288 - accuracy: 0.6250 - val_loss: 7.2082 - val_accuracy: 0.1613
# Epoch 54/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9354 - accuracy: 0.6311 - val_loss: 5.1194 - val_accuracy: 0.1075
# Epoch 55/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9284 - accuracy: 0.6189 - val_loss: 4.0958 - val_accuracy: 0.2688
# Epoch 56/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.9082 - accuracy: 0.6517 - val_loss: 4.5334 - val_accuracy: 0.1828
# Epoch 57/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8619 - accuracy: 0.6529 - val_loss: 3.5086 - val_accuracy: 0.3011
# Epoch 58/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.8823 - accuracy: 0.6566 - val_loss: 2.3980 - val_accuracy: 0.4301
# Epoch 59/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.8567 - accuracy: 0.6505 - val_loss: 4.9513 - val_accuracy: 0.1505
# Epoch 60/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8810 - accuracy: 0.6578 - val_loss: 3.1996 - val_accuracy: 0.3441
# Epoch 61/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8390 - accuracy: 0.6748 - val_loss: 2.3549 - val_accuracy: 0.3226
# Epoch 62/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8759 - accuracy: 0.6383 - val_loss: 3.1801 - val_accuracy: 0.3118
# Epoch 63/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8054 - accuracy: 0.6857 - val_loss: 2.0002 - val_accuracy: 0.4086
# Epoch 64/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8193 - accuracy: 0.6905 - val_loss: 3.4986 - val_accuracy: 0.3226
# Epoch 65/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7710 - accuracy: 0.6881 - val_loss: 3.4315 - val_accuracy: 0.3548
# Epoch 66/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7581 - accuracy: 0.6990 - val_loss: 3.5508 - val_accuracy: 0.3226
# Epoch 67/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.7721 - accuracy: 0.7184 - val_loss: 2.8564 - val_accuracy: 0.3548
# Epoch 68/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8168 - accuracy: 0.6650 - val_loss: 1.9354 - val_accuracy: 0.4301
# Epoch 69/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7867 - accuracy: 0.6966 - val_loss: 3.6669 - val_accuracy: 0.3118
# Epoch 70/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7185 - accuracy: 0.7063 - val_loss: 4.6185 - val_accuracy: 0.2903
# Epoch 71/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7294 - accuracy: 0.7124 - val_loss: 4.3640 - val_accuracy: 0.2366
# Epoch 72/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6529 - accuracy: 0.7451 - val_loss: 4.5585 - val_accuracy: 0.2366
# Epoch 73/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6705 - accuracy: 0.7342 - val_loss: 3.8685 - val_accuracy: 0.3226
# Epoch 74/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6956 - accuracy: 0.7282 - val_loss: 2.0470 - val_accuracy: 0.4086
# Epoch 75/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7202 - accuracy: 0.7391 - val_loss: 5.2801 - val_accuracy: 0.3118
# Epoch 76/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.8007 - accuracy: 0.6808 - val_loss: 2.2086 - val_accuracy: 0.3656
# Epoch 77/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6500 - accuracy: 0.7633 - val_loss: 2.3381 - val_accuracy: 0.4301
# Epoch 78/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7079 - accuracy: 0.7403 - val_loss: 2.0134 - val_accuracy: 0.4409
# Epoch 79/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7044 - accuracy: 0.7221 - val_loss: 2.5645 - val_accuracy: 0.3656
# Epoch 80/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.7501 - accuracy: 0.7148 - val_loss: 2.6023 - val_accuracy: 0.3763
# Epoch 81/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7211 - accuracy: 0.7245 - val_loss: 3.6761 - val_accuracy: 0.3548
# Epoch 82/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6778 - accuracy: 0.7367 - val_loss: 2.9734 - val_accuracy: 0.3548
# Epoch 83/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6389 - accuracy: 0.7451 - val_loss: 4.3490 - val_accuracy: 0.3118
# Epoch 84/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6201 - accuracy: 0.7718 - val_loss: 3.4492 - val_accuracy: 0.3763
# Epoch 85/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.5672 - accuracy: 0.7864 - val_loss: 2.0587 - val_accuracy: 0.4409
# Epoch 86/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5247 - accuracy: 0.7985 - val_loss: 5.3833 - val_accuracy: 0.2796
# Epoch 87/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5796 - accuracy: 0.7633 - val_loss: 4.9031 - val_accuracy: 0.3441
# Epoch 88/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6781 - accuracy: 0.7282 - val_loss: 2.9667 - val_accuracy: 0.4086
# Epoch 89/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6232 - accuracy: 0.7633 - val_loss: 2.5964 - val_accuracy: 0.3548
# Epoch 90/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5486 - accuracy: 0.7840 - val_loss: 4.3368 - val_accuracy: 0.3118
# Epoch 91/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5312 - accuracy: 0.7888 - val_loss: 3.5840 - val_accuracy: 0.4086
# Epoch 92/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5509 - accuracy: 0.7840 - val_loss: 9.1998 - val_accuracy: 0.2366
# Epoch 93/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5955 - accuracy: 0.7755 - val_loss: 6.8302 - val_accuracy: 0.2688
# Epoch 94/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5994 - accuracy: 0.7694 - val_loss: 4.1390 - val_accuracy: 0.3118
# Epoch 95/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5348 - accuracy: 0.7840 - val_loss: 2.9903 - val_accuracy: 0.3656
# Epoch 96/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6732 - accuracy: 0.7294 - val_loss: 4.5283 - val_accuracy: 0.3441
# Epoch 97/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6041 - accuracy: 0.7549 - val_loss: 3.3791 - val_accuracy: 0.3656
# Epoch 98/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4992 - accuracy: 0.7998 - val_loss: 4.9336 - val_accuracy: 0.3333
# Epoch 99/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5306 - accuracy: 0.8022 - val_loss: 5.9499 - val_accuracy: 0.3118
# Epoch 100/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5124 - accuracy: 0.8095 - val_loss: 5.9880 - val_accuracy: 0.3011
# Epoch 101/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5677 - accuracy: 0.7779 - val_loss: 4.9147 - val_accuracy: 0.3333
# Epoch 102/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.5162 - accuracy: 0.7888 - val_loss: 4.8940 - val_accuracy: 0.2903
# Epoch 103/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5162 - accuracy: 0.7961 - val_loss: 2.4529 - val_accuracy: 0.3871
# Epoch 104/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4377 - accuracy: 0.8216 - val_loss: 2.2409 - val_accuracy: 0.4516
# Epoch 105/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4215 - accuracy: 0.8495 - val_loss: 3.3185 - val_accuracy: 0.4301
# Epoch 106/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4148 - accuracy: 0.8277 - val_loss: 2.6829 - val_accuracy: 0.4946
# Epoch 107/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.4680 - accuracy: 0.8337 - val_loss: 2.4320 - val_accuracy: 0.4731
# Epoch 108/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3922 - accuracy: 0.8580 - val_loss: 3.1688 - val_accuracy: 0.4516
# Epoch 109/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4474 - accuracy: 0.8325 - val_loss: 2.7547 - val_accuracy: 0.3871
# Epoch 110/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.3585 - accuracy: 0.8677 - val_loss: 3.2144 - val_accuracy: 0.4194
# Epoch 111/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3101 - accuracy: 0.8835 - val_loss: 2.5969 - val_accuracy: 0.3978
# Epoch 112/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3193 - accuracy: 0.8993 - val_loss: 2.2996 - val_accuracy: 0.4946
# Epoch 113/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3584 - accuracy: 0.8568 - val_loss: 3.8597 - val_accuracy: 0.3871
# Epoch 114/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3793 - accuracy: 0.8604 - val_loss: 2.6962 - val_accuracy: 0.3656
# Epoch 115/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3310 - accuracy: 0.8738 - val_loss: 5.0682 - val_accuracy: 0.3441
# Epoch 116/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3830 - accuracy: 0.8459 - val_loss: 2.5116 - val_accuracy: 0.4516
# Epoch 117/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3811 - accuracy: 0.8556 - val_loss: 3.4663 - val_accuracy: 0.3548
# Epoch 118/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3328 - accuracy: 0.8774 - val_loss: 3.4363 - val_accuracy: 0.3441
# Epoch 119/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.3481 - accuracy: 0.8629 - val_loss: 3.5674 - val_accuracy: 0.3656
# Epoch 120/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2896 - accuracy: 0.8981 - val_loss: 3.0961 - val_accuracy: 0.3978
# Epoch 121/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2577 - accuracy: 0.8968 - val_loss: 3.0355 - val_accuracy: 0.4946
# Epoch 122/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3890 - accuracy: 0.8556 - val_loss: 3.3459 - val_accuracy: 0.4194
# Epoch 123/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3813 - accuracy: 0.8677 - val_loss: 3.6662 - val_accuracy: 0.4516
# Epoch 124/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3993 - accuracy: 0.8519 - val_loss: 5.0013 - val_accuracy: 0.3978
# Epoch 125/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4283 - accuracy: 0.8374 - val_loss: 5.7741 - val_accuracy: 0.3118
# Epoch 126/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4191 - accuracy: 0.8568 - val_loss: 8.7003 - val_accuracy: 0.3118
# Epoch 127/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3309 - accuracy: 0.8726 - val_loss: 4.0086 - val_accuracy: 0.4086
# Epoch 128/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.3759 - accuracy: 0.8568 - val_loss: 2.9059 - val_accuracy: 0.4086
# Epoch 129/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3667 - accuracy: 0.8738 - val_loss: 2.3562 - val_accuracy: 0.5054
# Epoch 130/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3278 - accuracy: 0.8799 - val_loss: 2.5587 - val_accuracy: 0.4839
# Epoch 131/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4225 - accuracy: 0.8459 - val_loss: 2.6943 - val_accuracy: 0.4624
# Epoch 132/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4240 - accuracy: 0.8568 - val_loss: 4.9552 - val_accuracy: 0.3763
# Epoch 133/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4266 - accuracy: 0.8386 - val_loss: 4.1259 - val_accuracy: 0.3871
# Epoch 134/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4089 - accuracy: 0.8714 - val_loss: 2.5847 - val_accuracy: 0.4086
# Epoch 135/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.3337 - accuracy: 0.8677 - val_loss: 2.3205 - val_accuracy: 0.4624
# Epoch 136/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2869 - accuracy: 0.8883 - val_loss: 3.7283 - val_accuracy: 0.4194
# Epoch 137/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.3142 - accuracy: 0.8823 - val_loss: 2.6383 - val_accuracy: 0.4194
# Epoch 138/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2500 - accuracy: 0.8968 - val_loss: 2.4325 - val_accuracy: 0.5161
# Epoch 139/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2944 - accuracy: 0.8920 - val_loss: 2.4502 - val_accuracy: 0.4731
# Epoch 140/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2055 - accuracy: 0.9199 - val_loss: 4.9407 - val_accuracy: 0.3333
# Epoch 141/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2788 - accuracy: 0.8908 - val_loss: 3.0996 - val_accuracy: 0.4731
# Epoch 142/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3302 - accuracy: 0.8799 - val_loss: 5.0305 - val_accuracy: 0.3226
# Epoch 143/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3042 - accuracy: 0.8859 - val_loss: 2.7940 - val_accuracy: 0.4409
# Epoch 144/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2926 - accuracy: 0.8896 - val_loss: 5.9229 - val_accuracy: 0.3333
# Epoch 145/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2410 - accuracy: 0.9090 - val_loss: 2.9294 - val_accuracy: 0.4301
# Epoch 146/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.3006 - accuracy: 0.8774 - val_loss: 2.2205 - val_accuracy: 0.5054
# Epoch 147/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1985 - accuracy: 0.9248 - val_loss: 3.1981 - val_accuracy: 0.4409
# Epoch 148/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2566 - accuracy: 0.9066 - val_loss: 2.0099 - val_accuracy: 0.5161
# Epoch 149/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2023 - accuracy: 0.9260 - val_loss: 3.2833 - val_accuracy: 0.4086
# Epoch 150/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2488 - accuracy: 0.9223 - val_loss: 2.2180 - val_accuracy: 0.5484
# Epoch 151/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2348 - accuracy: 0.9260 - val_loss: 4.4992 - val_accuracy: 0.4194
# Epoch 152/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2507 - accuracy: 0.9005 - val_loss: 2.5521 - val_accuracy: 0.4839
# Epoch 153/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2197 - accuracy: 0.9248 - val_loss: 2.9563 - val_accuracy: 0.4731
# Epoch 154/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2285 - accuracy: 0.9102 - val_loss: 2.5518 - val_accuracy: 0.4731
# Epoch 155/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1679 - accuracy: 0.9417 - val_loss: 2.4355 - val_accuracy: 0.5484
# Epoch 156/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1730 - accuracy: 0.9454 - val_loss: 2.6005 - val_accuracy: 0.4946
# Epoch 157/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1391 - accuracy: 0.9454 - val_loss: 1.9869 - val_accuracy: 0.5376
# Epoch 158/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1764 - accuracy: 0.9345 - val_loss: 2.9187 - val_accuracy: 0.5161
# Epoch 159/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1636 - accuracy: 0.9442 - val_loss: 2.6177 - val_accuracy: 0.5484
# Epoch 160/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1857 - accuracy: 0.9272 - val_loss: 2.8643 - val_accuracy: 0.5269
# Epoch 161/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2294 - accuracy: 0.9175 - val_loss: 2.3627 - val_accuracy: 0.5376
# Epoch 162/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.2130 - accuracy: 0.9187 - val_loss: 3.7591 - val_accuracy: 0.4516
# Epoch 163/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2407 - accuracy: 0.9029 - val_loss: 2.5484 - val_accuracy: 0.5376
# Epoch 164/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3276 - accuracy: 0.8908 - val_loss: 3.0324 - val_accuracy: 0.5054
# Epoch 165/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3426 - accuracy: 0.8799 - val_loss: 4.3085 - val_accuracy: 0.3441
# Epoch 166/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3023 - accuracy: 0.8859 - val_loss: 3.0134 - val_accuracy: 0.3871
# Epoch 167/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2033 - accuracy: 0.9199 - val_loss: 3.5570 - val_accuracy: 0.4409
# Epoch 168/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2439 - accuracy: 0.9017 - val_loss: 6.5559 - val_accuracy: 0.2903
# Epoch 169/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1985 - accuracy: 0.9284 - val_loss: 5.1813 - val_accuracy: 0.4516
# Epoch 170/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.2154 - accuracy: 0.9235 - val_loss: 2.9059 - val_accuracy: 0.5269
# Epoch 171/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1879 - accuracy: 0.9320 - val_loss: 2.4629 - val_accuracy: 0.4946
# Epoch 172/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1446 - accuracy: 0.9430 - val_loss: 3.3127 - val_accuracy: 0.4839
# Epoch 173/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1520 - accuracy: 0.9466 - val_loss: 3.3157 - val_accuracy: 0.4516
# Epoch 174/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1877 - accuracy: 0.9308 - val_loss: 4.3759 - val_accuracy: 0.3763
# Epoch 175/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1812 - accuracy: 0.9284 - val_loss: 2.3337 - val_accuracy: 0.5591
# Epoch 176/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1746 - accuracy: 0.9345 - val_loss: 2.9066 - val_accuracy: 0.4839
# Epoch 177/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2262 - accuracy: 0.9211 - val_loss: 3.6745 - val_accuracy: 0.4194
# Epoch 178/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2092 - accuracy: 0.9223 - val_loss: 4.2299 - val_accuracy: 0.3763
# Epoch 179/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1780 - accuracy: 0.9308 - val_loss: 4.2236 - val_accuracy: 0.4516
# Epoch 180/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.1980 - accuracy: 0.9284 - val_loss: 6.1321 - val_accuracy: 0.3441
# Epoch 181/200
# 7/7 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9563
# Akurasi mencapai 95%
# 7/7 [==============================] - 11s 2s/step - loss: 0.1375 - accuracy: 0.9563 - val_loss: 2.4042 - val_accuracy: 0.4946

# %%
val_generator=val_datagen.flow_from_directory(
    validation_dir,
    target_size=(227,227),
    batch_size=32,
    class_mode ='categorical'
)
# Out:
# Found 93 images belonging to 7 classes.

# %%
preds = alex.evaluate(val_generator)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 3/3 [==============================] - 2s 455ms/step - loss: 2.2318 - accuracy: 0.5376
# Loss = 2.231839656829834
# Test Accuracy = 0.5376344323158264

# %% [markdown]
# # **Lets Classify!!**

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

plt.plot(epochs,acc,'r',label='training accuracy')
plt.plot(epochs,val_acc,'g',label='validation accuracy')
plt.title('akurasi validasi dan training')
plt.legend(loc='best')
plt.show()

plt.plot(epochs,loss,'r',label='training loss')
plt.plot(epochs,val_loss,'g',label='validation loss')
plt.title('loss validasi dan training')
plt.legend(loc='best')
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files
class_list=os.listdir(train_dir)
print('Data dapat dikelompokan menjadi: ', class_list)
uploaded=files.upload()

for fn in uploaded.keys():

  path=fn
  img=image.load_img(path,target_size=(227,227))
  imgplot=plt.imshow(img)
  img_array = tf.keras.utils.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0) # Create a batch
  predictions = alex.predict_generator(img_array)
  score = tf.nn.softmax(predictions[0])
  print(
      "This image most likely belongs to {} with a {:.2f} percent confidence."
      .format(class_list[np.argmax(score)], 100 * np.max(score))
      )
# Out:
# Data dapat dikelompokan menjadi:  ['light_dysplastic', 'moderate_dysplastic', 'carcinoma_in_situ', 'normal_superficiel', 'normal_intermediate', 'severe_dysplastic', 'normal_columnar']
#      <input type="file" id="files-6ff27332-1a49-4769-88d0-dd3395b2c78d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ff27332-1a49-4769-88d0-dd3395b2c78d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 149056321-149056343-001.jpg to 149056321-149056343-001.jpg
# This image most likely belongs to normal_superficiel with a 31.18 percent confidence.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   from ipykernel import kernelapp as app

# %% [markdown]
# note: for 'prediksi' folder make sure that we place the image inside 1 folder first, so the system will read there is some images in 1 classes

# %%
#untuk gambar lain
prediksi='/content/drive/MyDrive/folderr/prediksi/'
predict_datagen=ImageDataGenerator(rescale=1./255)
predict=predict_datagen.flow_from_directory(
    prediksi,
    target_size=(227,227),
    batch_size=1,
    class_mode='categorical'
)


image_num=5
predictions = alex.predict(predict)
imshow(predict[image_num][0][0])
print(predictions[image_num])

nilai = tf.nn.softmax(predictions[image_num])

print(
      "Ini adalah gambar {} dengan persentase keyakinan {:.2f}"
      .format(class_list[np.argmax(nilai)], 100 * np.max(nilai))
      )
print(class_list[np.argmax(nilai)])
# Out:
# Found 21 images belonging to 1 classes.
# [1.2278972e-10 1.4419412e-05 1.1985595e-09 1.4653985e-11 9.9699402e-01
#  2.9916523e-03 6.6641179e-11]
# Ini adalah gambar normal_intermediate dengan persentase keyakinan 31.10
# normal_intermediate

# %%
# gambar1
nilai_pred1=tf.nn.softmax(predictions[13])
pred1=class_list[np.argmax(nilai_pred1)]
perstage1=100 * np.max(nilai_pred1)
judul1="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred1)], 100 * np.max(nilai_pred1))
#gambar2
nilai_pred2=tf.nn.softmax(predictions[10])
pred2=class_list[np.argmax(nilai_pred2)]
perstage2=100 * np.max(nilai_pred2)
judul2="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred2)], 100 * np.max(nilai_pred2))
#gambar3
nilai_pred3=tf.nn.softmax(predictions[5])
pred3=class_list[np.argmax(nilai_pred3)]
perstage3=100 * np.max(nilai_pred3)
judul3="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred3)], 100 * np.max(nilai_pred3))
#gambar4
nilai_pred4=tf.nn.softmax(predictions[18])
pred4=class_list[np.argmax(nilai_pred4)]
perstage4=100 * np.max(nilai_pred4)
judul4="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred4)], 100 * np.max(nilai_pred4))
#gambar5
nilai_pred5=tf.nn.softmax(predictions[7])
pred5=class_list[np.argmax(nilai_pred5)]
perstage5=100 * np.max(nilai_pred5)
judul5="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred5)], 100 * np.max(nilai_pred5))
#gambar6
nilai_pred6=tf.nn.softmax(predictions[6])
pred6=class_list[np.argmax(nilai_pred6)]
perstage6=100 * np.max(nilai_pred6)
judul6="{}  {:.2f}%".format(class_list[np.argmax(nilai_pred6)], 100 * np.max(nilai_pred6))

#def get_category(predicted_output):
#  class_list
#  return os.listdir(train_dir)[np.argmax(abc)]
#-somehow fuction above can be used to shortening this part

# %%
fig , axs = plt.subplots(2,3 ,figsize = (10,10))

axs[0][0].imshow(predict[13][0][0])
axs[0][0].set_title(judul1)

axs[0][1].imshow(predict[10][0][0])
axs[0][1].set_title(judul2)

axs[0][2].imshow(predict[5][0][0])
axs[0][2].set_title(judul3)

axs[1][0].imshow(predict[18][0][0])
axs[1][0].set_title(judul4)

axs[1][1].imshow(predict[7][0][0])
axs[1][1].set_title(judul5)

axs[1][2].imshow(predict[6][0][0])
axs[1][2].set_title(judul6)
# Out:
# Text(0.5, 1.0, 'carcinoma_in_situ  31.18%')
